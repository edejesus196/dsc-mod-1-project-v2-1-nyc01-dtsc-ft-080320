# %%
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt

# %%
filenames = ['bom.movie_gross.csv','name.basics.csv','title.akas.csv','title.basics.csv','title.crew.csv','title.principals.csv','title.ratings.csv','tmdb.movies.csv','tn.movie_budgets.csv']

movies_df = []
for filename in filenames:
    movies_df.append(pd.read_csv('zippedData/' + filename))
    
movies_df[7]
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
movies_gross = pd.read_csv('./zippedData/bom.movie_gross.csv')
names_basics = pd.read_csv('./zippedData/name.basics.csv')
movies_info = pd.read_csv('./zippedData/rt.movie_info.tsv', sep= '\t')
#movie_reviews = pd.read_csv('./zippedData/rt.reviews.tsv', sep= '\t')
movies_akas = pd.read_csv('./zippedData/title.akas.csv', index_col='title_id')
movies_basics = pd.read_csv('./zippedData/title.basics.csv', index_col='tconst')
movies_crews = pd.read_csv('./zippedData/title.crew.csv', index_col='tconst')
movies_principals = pd.read_csv('./zippedData/title.principals.csv', index_col='tconst')
movies_tmdb_movies = pd.read_csv('zippedData/tmdb.movies.csv', index_col='id')

movies_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movies_basics.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
movies_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
movies_akas.head()
# Out:
#            ordering                                    title region language  \
# title_id
# tt0369610        10                            Джурасик свят     BG       bg
# tt0369610        11                        Jurashikku warudo     JP      NaN
# tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR      NaN
# tt0369610        13                  O Mundo dos Dinossauros     BR      NaN
# tt0369610        14                           Jurassic World     FR      NaN
#
#                  types   attributes  is_original_title
# title_id
# tt0369610          NaN          NaN                0.0
# tt0369610  imdbDisplay          NaN                0.0
# tt0369610  imdbDisplay          NaN                0.0
# tt0369610          NaN  short title                0.0
# tt0369610  imdbDisplay          NaN                0.0

# %%
movies_basics.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
movies_crews.head()
# Out:
#                                directors              writers
# tconst
# tt0285252                      nm0899854            nm0899854
# tt0438973                            NaN  nm0175726,nm1802864
# tt0462036                      nm1940585            nm1940585
# tt0835418                      nm0151540  nm0310087,nm0841532
# tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
movies_principals.head()
# Out:
#            ordering     nconst  category       job        characters
# tconst
# tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# tt0111414         2  nm0398271  director       NaN               NaN
# tt0111414         3  nm3739909  producer  producer               NaN
# tt0323808        10  nm0059247    editor       NaN               NaN
# tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
movies_tmdb_movies.head()
# Out:
#        Unnamed: 0            genre_ids original_language  \
# id
# 12444           0      [12, 14, 10751]                en
# 10191           1  [14, 12, 16, 10751]                en
# 10138           2        [12, 28, 878]                en
# 862             3      [16, 35, 10751]                en
# 27205           4        [28, 878, 12]                en
#
#                                      original_title  popularity release_date  \
# id
# 12444  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 10191                      How to Train Your Dragon      28.734   2010-03-26
# 10138                                    Iron Man 2      28.515   2010-05-07
# 862                                       Toy Story      28.005   1995-11-22
# 27205                                     Inception      27.920   2010-07-16
#
#                                               title  vote_average  vote_count
# id
# ...

# %%
movies_gross_sorted = movies_gross.sort_values(['year', 'domestic_gross'], ascending=(False, False))
movies_gross_sorted.head(20)
# Out:
#                                             title studio  domestic_gross  \
# 3080                                Black Panther     BV     700100000.0
# 3079                       Avengers: Infinity War     BV     678800000.0
# 3082                                Incredibles 2     BV     608600000.0
# 3081               Jurassic World: Fallen Kingdom   Uni.     417700000.0
# 3083                                      Aquaman     WB     335100000.0
# 3087                                   Deadpool 2    Fox     318500000.0
# 3096                 Dr. Seuss' The Grinch (2018)   Uni.     270600000.0
# 3086                Mission: Impossible - Fallout   Par.     220200000.0
# 3089                         Ant-Man and the Wasp     BV     216600000.0
# 3084                            Bohemian Rhapsody    Fox     216400000.0
# 3098                        A Star is Born (2018)     WB     215300000.0
# 3101                      Solo: A Star Wars Story     BV     213800000.0
# ...

# %%
url = 'https://api.themoviedb.org/3/movie/550?api_key=d3bf69e4b06ff86e7e373d85dc5a98bf'
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
numbers_movies_data = pd.read_csv('numbers.MovieData.csv', index_col='movie_odid')
numbers_movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1936 entries, 8220100 to 222990100
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_name                1936 non-null   object
#  1   production_year           1936 non-null   int64
#  2   production_budget         1936 non-null   int64
#  3   domestic_box_office       1936 non-null   int64
#  4   international_box_office  1936 non-null   int64
#  5   rating                    1913 non-null   object
#  6   creative_type             1923 non-null   object
#  7   source                    1915 non-null   object
#  8   production_method         1925 non-null   object
#  9   genre                     1926 non-null   object
#  10  sequel                    1934 non-null   float64
#  11  running_time              1822 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 196.6+ KB
